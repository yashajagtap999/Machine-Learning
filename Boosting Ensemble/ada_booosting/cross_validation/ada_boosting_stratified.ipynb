# %%
from sklearn.datasets import load_breast_cancer
from sklearn.ensemble import AdaBoostClassifier
from sklearn.model_selection import StratifiedKFold, cross_val_score
import numpy as np

# =====================================================
# Load Dataset
# =====================================================

data = load_breast_cancer()

X = data.data
y = data.target

# =====================================================
# AdaBoost Classifier
# =====================================================

model = AdaBoostClassifier(
    n_estimators=100,
    learning_rate=1.0,
    random_state=42
)

# =====================================================
# Stratified K-Fold Cross Validation
# =====================================================

skf = StratifiedKFold(
    n_splits=5,
    shuffle=True,
    random_state=42
)

scores = cross_val_score(
    model,
    X,
    y,
    cv=skf,
    scoring='accuracy'
)

# =====================================================
# Results
# =====================================================

print("Stratified K-Fold Accuracy Scores:")
for i, score in enumerate(scores, start=1):
    print(f"Fold {i}: {score:.4f}")

print("\nMean Accuracy: {:.4f}".format(np.mean(scores)))
print("Standard Deviation: {:.4f}".format(np.std(scores)))
print("Accuracy Percentage: {:.2f}%".format(np.mean(scores) * 100))
# Out:
# Cross Validation Scores: [0.96666667 0.96666667 0.93333333 0.9        1.        ]
# Mean Accuracy: 0.9533333333333334
# Standard Deviation: 0.03399346342395189
