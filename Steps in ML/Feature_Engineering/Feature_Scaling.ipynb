# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings # used to avoid the warning
warnings.filterwarnings("ignore")

# %%
df=pd.read_csv("insurance.csv")
df
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %% [markdown]
# Preprocessing

# %%
df_cleaned=df.copy()

# %%
print(df_cleaned.dtypes)
# Out:
# age           int64
# sex          object
# bmi         float64
# children      int64
# smoker       object
# region       object
# charges     float64
# dtype: object

# %%
# As the region columns consists of more than one types of value we need to apply one hot encoding here:--

# %%
df_cleaned=pd.get_dummies(df_cleaned,columns=["region"],drop_first=True)

# %%
df_cleaned
# Out:
#       age  sex     bmi  children  smoker      charges  region_northwest  \
# 0      19    1  27.900         0       1  16884.92400             False
# 1      18    0  33.770         1       0   1725.55230             False
# 2      28    0  33.000         3       0   4449.46200             False
# 3      33    0  22.705         0       0  21984.47061              True
# 4      32    0  28.880         0       0   3866.85520              True
# ...   ...  ...     ...       ...     ...          ...               ...
# 1333   50    0  30.970         3       0  10600.54830              True
# 1334   18    1  31.920         0       0   2205.98080             False
# 1335   18    1  36.850         0       0   1629.83350             False
# 1336   21    1  25.800         0       0   2007.94500             False
# 1337   61    1  29.070         0       1  29141.36030              True
#
#       region_southeast  region_southwest
# 0                False              True
# 1                 True             False
# 2                 True             False
# 3                False             False
# 4                False             False
# ...                ...               ...
# 1333             False             False
# 1334             False             False
# 1335              True             False
# 1336             False              True
# 1337             False             False
#
# [1338 rows x 9 columns]

# %%
df_cleaned=df_cleaned.astype(int)
df_cleaned
# Out:
#       age  sex  bmi  children  smoker  charges  region_northwest  \
# 0      19    1   27         0       1    16884                 0
# 1      18    0   33         1       0     1725                 0
# 2      28    0   33         3       0     4449                 0
# 3      33    0   22         0       0    21984                 1
# 4      32    0   28         0       0     3866                 1
# ...   ...  ...  ...       ...     ...      ...               ...
# 1333   50    0   30         3       0    10600                 1
# 1334   18    1   31         0       0     2205                 0
# 1335   18    1   36         0       0     1629                 0
# 1336   21    1   25         0       0     2007                 0
# 1337   61    1   29         0       1    29141                 1
#
#       region_southeast  region_southwest
# 0                    0                 1
# 1                    1                 0
# 2                    1                 0
# 3                    0                 0
# 4                    0                 0
# ...                ...               ...
# 1333                 0                 0
# 1334                 0                 0
# 1335                 1                 0
# 1336                 0                 1
# 1337                 0                 0
#
# [1338 rows x 9 columns]

# %% [markdown]
# Feature Engineering :-- it is a process of adding features to get high accuracy

# %%
df_cleaned["m_bmi"]=pd.cut(df_cleaned["bmi"],
                   bins=[10,20,30,40,float("inf")],
                   labels=["low","mid","high","vhigh"])

# %%
df_cleaned
# Out:
#       age     sex     bmi  children smoker     region      charges  m_bmi_low  \
# 0      19  female  27.900         0    yes  southwest  16884.92400      False
# 1      18    male  33.770         1     no  southeast   1725.55230      False
# 2      28    male  33.000         3     no  southeast   4449.46200      False
# 3      33    male  22.705         0     no  northwest  21984.47061      False
# 4      32    male  28.880         0     no  northwest   3866.85520      False
# ...   ...     ...     ...       ...    ...        ...          ...        ...
# 1333   50    male  30.970         3     no  northwest  10600.54830      False
# 1334   18  female  31.920         0     no  northeast   2205.98080      False
# 1335   18  female  36.850         0     no  southeast   1629.83350      False
# 1336   21  female  25.800         0     no  southwest   2007.94500      False
# 1337   61  female  29.070         0    yes  northwest  29141.36030      False
#
#       m_bmi_mid  m_bmi_high  m_bmi_vhigh m_bmi
# 0          True       False        False   mid
# 1         False        True        False  high
# 2         False        True        False  high
# 3          True       False        False   mid
# 4          True       False        False   mid
# ...         ...         ...          ...   ...
# 1333      False        True        False  high
# 1334      False        True        False  high
# 1335      False        True        False  high
# 1336       True       False        False   mid
# 1337       True       False        False   mid
#
# [1338 rows x 12 columns]

# %%
df_cleaned=pd.get_dummies(df_cleaned,columns=["m_bmi"])
df_cleaned
# Out:
#       age     sex     bmi  children smoker     region      charges  m_bmi_low  \
# 0      19  female  27.900         0    yes  southwest  16884.92400      False
# 1      18    male  33.770         1     no  southeast   1725.55230      False
# 2      28    male  33.000         3     no  southeast   4449.46200      False
# 3      33    male  22.705         0     no  northwest  21984.47061      False
# 4      32    male  28.880         0     no  northwest   3866.85520      False
# ...   ...     ...     ...       ...    ...        ...          ...        ...
# 1333   50    male  30.970         3     no  northwest  10600.54830      False
# 1334   18  female  31.920         0     no  northeast   2205.98080      False
# 1335   18  female  36.850         0     no  southeast   1629.83350      False
# 1336   21  female  25.800         0     no  southwest   2007.94500      False
# 1337   61  female  29.070         0    yes  northwest  29141.36030      False
#
#       m_bmi_mid  m_bmi_high  m_bmi_vhigh  m_bmi_low  m_bmi_mid  m_bmi_high  \
# 0          True       False        False      False       True       False
# 1         False        True        False      False      False        True
# 2         False        True        False      False      False        True
# 3          True       False        False      False       True       False
# 4          True       False        False      False       True       False
# ...         ...         ...          ...        ...        ...         ...
# 1333      False        True        False      False      False        True
# 1334      False        True        False      False      False        True
# 1335      False        True        False      False      False        True
# 1336       True       False        False      False       True       False
# 1337       True       False        False      False       True       False
#
#       m_bmi_vhigh
# 0           False
# 1           False
# 2           False
# 3           False
# 4           False
# ...           ...
# 1333        False
# 1334        False
# 1335        False
# 1336        False
# 1337        False
#
# [1338 rows x 15 columns]

# %%
df_cleaned
# Out:
#       age     sex     bmi  children smoker     region      charges  m_bmi_low  \
# 0      19  female  27.900         0    yes  southwest  16884.92400      False
# 1      18    male  33.770         1     no  southeast   1725.55230      False
# 2      28    male  33.000         3     no  southeast   4449.46200      False
# 3      33    male  22.705         0     no  northwest  21984.47061      False
# 4      32    male  28.880         0     no  northwest   3866.85520      False
# ...   ...     ...     ...       ...    ...        ...          ...        ...
# 1333   50    male  30.970         3     no  northwest  10600.54830      False
# 1334   18  female  31.920         0     no  northeast   2205.98080      False
# 1335   18  female  36.850         0     no  southeast   1629.83350      False
# 1336   21  female  25.800         0     no  southwest   2007.94500      False
# 1337   61  female  29.070         0    yes  northwest  29141.36030      False
#
#       m_bmi_mid  m_bmi_high  m_bmi_vhigh  m_bmi_low  m_bmi_mid  m_bmi_high  \
# 0          True       False        False      False       True       False
# 1         False        True        False      False      False        True
# 2         False        True        False      False      False        True
# 3          True       False        False      False       True       False
# 4          True       False        False      False       True       False
# ...         ...         ...          ...        ...        ...         ...
# 1333      False        True        False      False      False        True
# 1334      False        True        False      False      False        True
# 1335      False        True        False      False      False        True
# 1336       True       False        False      False       True       False
# 1337       True       False        False      False       True       False
#
#       m_bmi_vhigh
# 0           False
# 1           False
# 2           False
# 3           False
# 4           False
# ...           ...
# 1333        False
# 1334        False
# 1335        False
# 1336        False
# 1337        False
#
# [1338 rows x 15 columns]

# %% [markdown]
# Feature Scaling:-- It is a process of bringing the values in a specific range

# %%
from sklearn.preprocessing import StandardScaler
col=["age","bmi","children"]
scaler=StandardScaler()
df_cleaned[col]=scaler.fit_transform(df_cleaned[col])

# %%
df_cleaned
# Out:
#            age     sex       bmi  children smoker     region      charges  \
# 0    -1.438764  female -0.453320 -0.908614    yes  southwest  16884.92400
# 1    -1.509965    male  0.509621 -0.078767     no  southeast   1725.55230
# 2    -0.797954    male  0.383307  1.580926     no  southeast   4449.46200
# 3    -0.441948    male -1.305531 -0.908614     no  northwest  21984.47061
# 4    -0.513149    male -0.292556 -0.908614     no  northwest   3866.85520
# ...        ...     ...       ...       ...    ...        ...          ...
# 1333  0.768473    male  0.050297  1.580926     no  northwest  10600.54830
# 1334 -1.509965  female  0.206139 -0.908614     no  northeast   2205.98080
# 1335 -1.509965  female  1.014878 -0.908614     no  southeast   1629.83350
# 1336 -1.296362  female -0.797813 -0.908614     no  southwest   2007.94500
# 1337  1.551686  female -0.261388 -0.908614    yes  northwest  29141.36030
#
#       m_bmi_low  m_bmi_mid  m_bmi_high  m_bmi_vhigh  m_bmi_low  m_bmi_mid  \
# 0         False       True       False        False      False       True
# 1         False      False        True        False      False      False
# 2         False      False        True        False      False      False
# 3         False       True       False        False      False       True
# 4         False       True       False        False      False       True
# ...         ...        ...         ...          ...        ...        ...
# 1333      False      False        True        False      False      False
# 1334      False      False        True        False      False      False
# 1335      False      False        True        False      False      False
# 1336      False       True       False        False      False       True
# 1337      False       True       False        False      False       True
#
#       m_bmi_high  m_bmi_vhigh
# 0          False        False
# 1           True        False
# 2           True        False
# 3          False        False
# 4          False        False
# ...          ...          ...
# 1333        True        False
# 1334        True        False
# 1335        True        False
# 1336       False        False
# 1337       False        False
#
# [1338 rows x 15 columns]
